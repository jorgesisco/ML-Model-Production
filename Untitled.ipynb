# %%
pip list
# Out:
# Package                           Version
# --------------------------------- -------------------
# absl-py                           0.13.0
# aiodns                            3.0.0
# aiohttp                           3.7.4.post0
# aiohttp-socks                     0.4.1
# aniso8601                         9.0.1
# anyio                             3.3.1
# appnope                           0.1.2
# argon2-cffi                       20.1.0
# astroid                           2.6.5
# astunparse                        1.6.3
# async-generator                   1.10
# async-timeout                     3.0.1
# attrs                             21.2.0
# autopep8                          1.5.7
# Babel                             2.9.1
# backcall                          0.2.0
# backports.entry-points-selectable 1.1.0
# beautifulsoup4                    4.10.0
# bleach                            3.3.1
# cachetools                        4.2.2
# cchardet                          2.1.7
# ...
